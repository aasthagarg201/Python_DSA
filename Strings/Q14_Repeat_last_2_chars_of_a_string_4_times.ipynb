# %% [raw]
# Repeat last 2 chars of a string 4 times

# %%
def insert_end(str):
    str1 = str[-2:]
    return str1 * 4
    
print(insert_end('Python'))  
print(insert_end('Exercises'))
# Out:
# onononon
# eseseses
