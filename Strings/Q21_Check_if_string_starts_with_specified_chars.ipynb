# %% [raw]
# Check if string starts with specified chars

# %%
str = "w3resource.com"

# Using the startswith() method to check if the string 'str' starts with the substring "w3r".

print(str.startswith("w3r"))
# Out:
# True
