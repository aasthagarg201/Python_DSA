# %%
#Displaying input in upper and lower case

# %%
x = input("What's your favorite language? ")
print("My favorite language is ", x.upper())
print("My favorite language is ", x.lower())
# Out:
# What's your favorite language?  english
# My favorite language is  ENGLISH
# My favorite language is  english
