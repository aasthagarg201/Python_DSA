# %%
#Swaping first and last characters of a string

# %%
def change_string(str1):
    return str1[-1:] + str1[1:-1] + str1[:1]

print(change_string('abcde'))
print(change_string('12345'))
# Out:
# ebcda
# 52341
