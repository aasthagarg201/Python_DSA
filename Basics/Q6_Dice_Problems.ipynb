# %%
#The Dice Problem

# %%
def oppositefaceofdice(n):
    x=7-n
    return x

n=2
print(oppositefaceofdice(n))
# Out:
# 5

# %%
def oppositefaceofdice(k):
    if k==1:
        return 6
    elif k==2:
        return 5
    elif k==3:
        return 4
    elif k==4:
        return 3
    elif k==5:
        return 2
    else:
        return 1
        
k=3
print(oppositefaceofdice(k))
# Out:
# 4
